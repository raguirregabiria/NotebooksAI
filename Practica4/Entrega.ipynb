# %% [markdown]
# # Práctica optimización
#
# Practica de la asignatura Agentes Inteligentes, hecha con el programa SALGA:
# https://gitlab.etsisi.upm.es/fserra/salga
#
# ## Realizada por:
#
# ### Rodrigo Aguirregabiria Herrero
# ### Manuel Alfredo Collado Centeno

# %% [markdown]
# En la entrega se adjuntan los .py modificados en la carpeta fitness.
#
# En la carpeta caminanteSoluciones añadimos capturas y la mejor solución que hemos encontrado

# %% [markdown]
# ### 1.Encontrar la ruta más corta posible para el tsp2d suministrado.

# %% [markdown]
# #### ¿Encuentra siempre la mejor solución? ¿Por qué?
#
# No siempre, es probable que caiga en mínimos locales.

# %% [markdown]
# #### ¿Crees que se puede estar seguro de haber encontrado la solución óptima?
#
#
# No, ya que explorar todas las posibles soluciones es computacionalmente inviable, como veremos a continuación

# %% [markdown]
# #### ¿Es útil repetir la optimización varias veces? ¿Por qué?

# %% [markdown]
# Sí. Puede ser más util si usamos distintos tipos de ajustes, así porbamos distintas maneras de aproximarnos a la solución.
#
# Si usamos el mismo también puede ser bueno, ya que se inicializa de manera distinta y seguramente dé otra soución, que puede ser mejor o peor.

# %% [markdown]
# #### Calcula el número de soluciones posibles y el tiempo que tardaría una máquina si generar cada una y comprobar su longitud le llevara un microsegundo

# %% [markdown]
# Tenemos N ciudades
#
# partiendo de 1 tenemos N -1 posibilidades
#
# Cogemos uno y tenemos N -2 posibilaadaes
#
# Es n!

# %%
cities = [[0.8744058793117488, 0.30207179832703746], [0.6901572276474558, 0.8203362566663311], [0.7793458478083026, 0.09728979746351918], [0.7483358474304422, 0.4563419482458657], [0.4556164527790729, 0.12863149772605698], [0.1837236688553453, 0.23773749495644914], [0.806151832654163, 0.3288366900529254], [0.6222702185205219, 0.6019431085670109], [0.21886861543988367, 0.6980104036528004], [0.9706096813038716, 0.054871876245520146], [0.13881496219356027, 0.048489530185603646], [0.08511086492841424, 0.9123075505436051], [0.45436952164297595, 0.4731540740573398], [0.8986352255038935, 0.5116579750591849], [0.9539248970461742, 0.7530784036308166], [0.6321102985156373, 0.13575967095580344], [0.31130918313591205, 0.8545457319320597], [0.025897479791937017, 0.7854526665590987], [0.31414095045738066, 0.051421702103483846], [0.2739561013272712, 0.1970964027924862], [0.22762328443470214, 0.627414210742153], [0.44920042912037383, 0.18835427573438068], [0.2793138301174244, 0.9103956650199608], [0.005128451667189338, 0.4655718085045638], [0.9222718335261915, 0.8613103704784812], [0.49352498279326595, 0.28652416807644077], [0.5560886356057152, 0.034564925228364185], [0.0048939219846825255, 0.8635350555457212], [0.7824462381771976, 0.09355415747424733], [0.2973635133076785, 0.037580527218207815], [0.659068210692151, 0.5602321147981546], [0.43549418718677035, 0.6241289474799954], [0.25580657871099755, 0.519726015381631], [0.5950780852425872, 0.3193476592023645], [0.15763623266223903, 0.18210618406479095], [0.3434173147566393, 0.32992255868483356], [0.06451313705472006, 0.12606114349173192], [0.23212286400737547, 0.3945559700824013], [0.955507285594692, 0.02296933408938162], [0.7459955912073274, 0.1385374827130177], [0.46365765315595475, 0.6132297411379687], [0.20196772698059162, 0.046358747430397584], [0.2980093518214506, 0.36041197123227897], [0.7533459401199348, 0.6610562232191091], [0.323433933838161, 0.5068337090138902], [0.062138830138457, 0.7177455044259695], [0.47467832142010535, 0.17692718986260936], [0.2415634321550142, 0.500852093941769], [0.3441878827094532, 0.2604351258948506], [0.5445252142594251, 0.7295590645635646], [0.25391391610860914, 0.7641244059389684], [0.2630560480211699, 0.010670642241309536], [0.2092202940037915, 0.7415775443241935], [0.0031474687633804566, 0.6974574785842637], [0.4952329615559806, 0.9311775894780175], [0.1978488658972426, 0.8872693649066419], [0.1705364411799497, 0.8846808176103278], [0.7634962513234275, 0.4358457309207533], [0.9259752834140167, 0.0056226911773098465], [0.22090405091557253, 0.14500040130773872], [0.4636205151855679, 0.19249574424477278], [0.8057632881682811, 0.250168118157608], [0.6785236695642043, 0.39119477830554505], [0.4837264739606879, 0.23045417711558214], [0.8786721718893166, 0.015853186240832207], [0.1263309724872509, 0.9185321014517236], [0.24969404380600335, 0.9600467657522086], [0.5886119367943214, 0.10948123668473264], [0.13373527735293878, 0.5336853876899833], [0.5642696742735989, 0.9801384844337597], [0.646401605512568, 0.3338636388089157], [0.05603526365085032, 0.3149530712641142], [0.387141492676661, 0.5792852545912592], [0.8634070619751958, 0.8206820685065667], [0.4662474858565825, 0.32647667516764145], [0.01801973379815025, 0.12175434785651695], [0.6218125565554127, 0.07860046445444713], [0.6573938922925594, 0.5023092428939168], [0.2837581848186974, 0.02576704782244421], [0.3044774374252185, 0.7310313422019327], [0.33131673439274434, 0.693896434962478], [0.8523694048117944, 0.2805224723356823], [0.6200019812032047, 0.03989814578273998], [0.5437394088109648, 0.3258031129949792], [0.4386079860370994, 0.6142798815693052], [0.7430581106897977, 0.49260737229959284], [0.3913628378102181, 0.3185830750836698], [0.9065498976196814, 0.02381958527497441], [0.6874236611131453, 0.18642068590773597], [0.6946411585627993, 0.36991609629423117], [0.3784063098306413, 0.01018756575849844], [0.43806374889930155, 0.2268325586117821], [0.7411632641820634, 0.35513151640087337], [0.3884706603234591, 0.34043302784114093], [0.08674110453583683, 0.4491174987265194], [0.9794883193315694, 0.11207520940235804], [0.7496156619797683, 0.23845386610980834], [0.4423888847621813, 0.17212722421686055], [0.2276570035864689, 0.6515924491551327], [0.836939257954547, 0.0499933914625984]] # Length=8.587

# %%
print(len(cities))
# Out:
# 100

# %%
#Factorial de 100
ms = 9.332622e+157
print(ms)
# Out:
# 9.332622e+157

# %%
#Pasamaos a segundos
s = ms / 1e+6
print(s)
# Out:
# 9.332622e+151

# %%
# Pasamos a años
year = (s/(60*60*24*365))
print(year)
# Out:
# 2.95935502283105e+144

# %% [markdown]
# Se tardarían esos años en comprobar todas las soluciones, backtraking solo sirve en problemas muy sencillos. Es relativamente sencillo encontrar un algoritmo que realice el cálculo, pero en la practica es inviable.

# %% [markdown]
# ## Problema del viajante

# %% [markdown]
# #### Usando Steady State

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Usando Steady State conseguimos una solución en la que el recorrido es de 7,693

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Por torneo

# %% [markdown]
# Usando un torneo de 50

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Mezclando elitismo con meméticos y Steady

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Usamos meméticos y elitismo. Meméticos hace que vaya más rápido que con elitismo solo, el problema es que cuando ya ha llegado a una solución relativamente buena (por debajo de 10) le cuesta mucho deshacer los cruces de camino.
#
# Para ello, cuando llega ese momento (señalado por la flecha), usamos steady y como vemos mejora la peor población, pero la diversidad cae en picado. Eso sí, deshace los cruces rapidamente.

# %% [markdown]
# ### Cervezas

# %%
#Codigo
M = 30 #Malta
L = 45 #Levadura

def phenotype (chromosome):
    return chromosome[0] * 4 + chromosome[1] * 7 + chromosome[2] * 3

def fitness (chromosome): # priorize ordered genes
    malta = chromosome[0] * 2 + chromosome[1] * 1 + chromosome[2] * 2
    levadura = chromosome[0] * 1 + chromosome[1] * 2 + chromosome[2] * 2
    if (malta > M) or (levadura > L): # No se puede pasar de ese limite.
        return 0
    beneficio = chromosome[0] * 4 + chromosome[1] * 7 + chromosome[2] * 3
    return beneficio

# El número meximo que puede haber es 22 rubias, de las otras como mucho habría 15.

parameters = { 'alphabet':list(range(23)), 'type':'classic', 'chromsize':3, 'target': 160 } # Target ponemos 160 porque es el máximo posible con estos recursos.

# %% [markdown]
# Aplicando elitismo llega a la solución relativamente rapido (184 generaciones) a la mejor solución (160 de beneficio), incluso hemos tenido que bajar a 1 la traza para que se vea la evolución.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Horarios

# %%
# Añadimos las siguientes modificaciones en el fitnes:
score += 50.0*franjas[5].count('Pla')/5.0 # matemáticas a primera hora (max: 20)

score += dias[0].count('MAE') * 20 # Maximo 20

#también modificamos el target hasta 100

# %% [markdown]
# De esta manera cumple todo lo anterior (Mates a primera y priorizar que las asignaturas mantengan el horario a lo largo de los días) y la nueva (MAE los lunes y plástica a última).
#
# Debajo enseñamos un ejemplo donde lo encuentra rapidamente, Steady afecta a la diversidad pero como cumple las exigencias tampoco es primordial buscar más soluciones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Regalos

# %% [markdown]
# Usando la configuración por defecto del archivo regalos.py encuentra la solución bastante rápido y siempre es la misma (alternando el orden, eso sí).
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Obtener 10 regalos en vez de 5
#
# En este caso la única manera de conseguirlo sería repitiendo regalo, ya que el presupuesto es limitado (300) y la solución ideal es gastarse en todos lo mismo (30), ya que la diferencia es la misma y se usa todo el presupuesto.
#
# ![image.png](attachment:image.png)
#
# Si quisiéramos que no se repitiesen habría que aumentar el presupuesto.

# %%
precios = [62,55,17,115,40,65,80,83,99,49,25,30,22,30,30,50,70,60,58,110]
estrellas = [1,4,3,2,5,1,1,2,5,4,3,4,4,3,2,3,5,4,4,5]
presupuesto = 390.0
precios.sort()
print(precios)
total= 0
for i in range (10):
    total+=precios[i]
print(total)
# Out:
# [17, 22, 25, 30, 30, 30, 40, 49, 50, 55, 58, 60, 62, 65, 70, 80, 83, 99, 110, 115]
# 348

# %% [markdown]
# Para que no se repitan el presupuesto debe de ser de 348, pero no encuentra la solución facilmente, modificamos el fitness para que divida entre 100 y no entre 10, ya que si no repite.
# ![image.png](attachment:image.png)
